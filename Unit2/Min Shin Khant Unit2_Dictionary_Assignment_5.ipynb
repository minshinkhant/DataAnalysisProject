# %% [markdown]
# <a href="https://colab.research.google.com/github/niteen11/lagcc_data_analytics_micro_credential/blob/master/Unit%202%20-%20Python%20Fundamentals/Assignments/Unit2_Dictionary_Assignment_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intrdouction to Python - Dictionary - Assignment #5

# %% [markdown]
# ## 1.	Create a simple dictionary that stores 2 variables, for example: first and last name.

# %%
my_full_name = {"first name": "Min Shin", "last name": "Khant"}

# %%
print(my_full_name)
# Out:
# {'first name': 'Min Shin', 'last name': 'Khant'}

# %% [markdown]
# ## 2.	Print out those variables stored in your previous dictionary.

# %%
for item in my_full_name:
  print(my_full_name[item])
# Out:
# Min Shin
# Khant

# %% [markdown]
# ## 3.	Add a message to those variables on printing: for example: “Hello, firstname lastname!”

# %%
for item in my_full_name:
  print("Hello", my_full_name[item], "!")
# Out:
# Hello Min Shin !
# Hello Khant !

# %% [markdown]
# ## 4.	Create a dictionary that holds 2 key: value pairs:
#
# a.	Look through your dictionary and print each pair,

# %%
my_full_name = {"first name": "Min Shin", "last name": "Khant"}

# %%
my_movies_list = {"1st one":"GOT", "2nd one":"Avengers"}

# %%
new_person = {"first name":"Nego","last name":"Jovanovich","age": 30, "city":"New York","Has Pet":True}

# %%
my_friends = {"John": 24, "Potter":25, "Peter": 35, "Marry": 45, "Summer":30}

# %%
vocab_words = {}
vocab_words["Python"] = "Programming Language"
vocab_words["SQL"] = "DataBase language"
vocab_words["NodeJS"] = "JavaScirpt runtime environment"

# %%
for key,value in vocab_words.items():
  print(key + " " + value)
# Out:
# Python Programming Language
# SQL DataBase languuage
# NodeJS JavaScirpt runtime environment

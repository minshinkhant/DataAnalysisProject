# %% [markdown]
# <a href="https://colab.research.google.com/github/niteen11/lagcc_data_analytics_micro_credential/blob/master/Unit%202%20-%20Python%20Fundamentals/Mini%20Project/Unit2_Mini_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intrdouction to Python - Mini Project

# %% [markdown]
# #Python Project – Odd or Even
#
# Ask the user for a number. Depending on whether the number is even or odd, print out an appropriate message to the user. Hint: how does an even / odd number react differently when divided by 2?

# %%
user_number = int(input("please put a number(a positive integer)!!!"))
if (user_number%2 == 0):
    print("You enter an even number.")
else:
    print("You enter an odd number.")
# Out:
# please put a number(a positive integer)!!!5
# You enter an odd number.

# %% [markdown]
# # Bonus:
#
# 1.	If the number is a multiple of 4, print out a different message.
#
# 2.	Ask the user for two numbers: one number to check (call it num) and one number to divide by (check). If check divides evenly into num, tell that to the user. If not, print a different appropriate message.

# %%
#If the number is a multiple of 4, print out a different message.

user_number = int(input("please put a number(a positive integer)!!!"))
if (user_number%4 == 0):
  print("You enter a multiple of 4.")
elif (user_number%2 == 0):
  print("You enter an even number.")
else:
  print("You enter an odd number.")
# Out:
# please put a number(a positive integer)!!!6
# You enter an even number.

# %%
num = int(input("Please enter the Divisor(a positive integer)!"))
check = int(input("Plase enter the Dividend(a positive integer)!"))

if(check%num == 0):
  print(check,"is a multiple of", num)
else:
  print(check,"is not a multiple of",num)
# Out:
# Please enter the Divisor(a positive integer)!2
# Plase enter the Dividend(a positive integer)!7
# 7 is not a multiple of 2

# %%
# Out:
# False

# %%
# Out:
# True

# %%
# Out:
# 0

# %%
#1
print("A" == "a")

#2
print(4 <= 5)

#3
movie = "avengers"

if movie == "matrix" or movie == "star wars":
  print("I have not watch that movie")
else:
  print("I should have watch it")

#4
my_fruit = ["apple", "orange", "watermelon", "peach"]

if "coconut" in my_fruit:
  print("Yes, it is in your fruit list")
else:
  print("Hell no")


#5
my_color = ["purple", "brown", "grey", "black", "white"]

if "yellow" not in my_color:
  print("Yes, you can use that color in the design")
else:
  print("Hell no")
# Out:
# I should have watch it
# Hell no
# Yes, you can use that color in the design

# %%
# Out:
# Yes, you can use that color in the design
